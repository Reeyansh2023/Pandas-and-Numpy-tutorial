# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # import data

# %%
df=pd.read_csv("gun-violence-data.csv")
df1=df.copy()
df1.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239677 entries, 0 to 239676
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_id                  239677 non-null  int64
#  1   date                         239677 non-null  object
#  2   state                        239677 non-null  object
#  3   city_or_county               239677 non-null  object
#  4   address                      223180 non-null  object
#  5   n_killed                     239677 non-null  int64
#  6   n_injured                    239677 non-null  int64
#  7   incident_url                 239677 non-null  object
#  8   source_url                   239209 non-null  object
#  9   incident_url_fields_missing  239677 non-null  bool
#  10  congressional_district       227733 non-null  float64
#  11  gun_stolen                   140179 non-null  object
# ...

# %%
df1=df1.iloc[:,:7]
df1.head(10)
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
# 5       478948  2013-01-07        Oklahoma          Tulsa
# 6       479363  2013-01-19      New Mexico    Albuquerque
# 7       479374  2013-01-21       Louisiana    New Orleans
# 8       479389  2013-01-21      California      Brentwood
# 9       492151  2013-01-23        Maryland      Baltimore
#
#                                              address  n_killed  n_injured
# 0          1506 Versailles Avenue and Coursin Street         0          4
# 1                       13500 block of Cerise Avenue         1          3
# 2                              1776 East 28th Street         1          3
# ...

# %%
df1.drop(columns=["incident_id","city_or_county","address"],inplace=True)

# %%
df1.head()
# Out:
#          date           state  n_killed  n_injured
# 0  2013-01-01    Pennsylvania         0          4
# 1  2013-01-01      California         1          3
# 2  2013-01-01            Ohio         1          3
# 3  2013-01-05        Colorado         4          0
# 4  2013-01-07  North Carolina         2          2

# %%
df1['day']=pd.to_datetime(df1["date"]).dt.day

# %%
df1['month']=pd.to_datetime(df1["date"]).dt.month

# %%
df1['year']=pd.to_datetime(df1["date"]).dt.year

# %%
df1["quarter"]=pd.to_datetime(df1["date"]).dt.quarter

# %%
df1["day_of_week_num"]=pd.to_datetime(df1["date"]).dt.dayofweek

# %%
df1["day_of_week_name"]=pd.to_datetime(df1["date"]).dt.day_name()

# %% [markdown]
# #### 2nd method day of week name
# ######  replace numeric day of week value with text

# %%
df1['day_of_week_num']=df1['day_of_week_num'].map({0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thrusday',4:'Friday',5:'Saturday',6:'Sunday'})

# %%
df1['month']=df1['month'].map({1:'January',2:'Febuary',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'})

# %%
df1.head()
# Out:
#          date           state  n_killed  n_injured  day    month  year  \
# 0  2013-01-01    Pennsylvania         0          4    1  January  2013
# 1  2013-01-01      California         1          3    1  January  2013
# 2  2013-01-01            Ohio         1          3    1  January  2013
# 3  2013-01-05        Colorado         4          0    5  January  2013
# 4  2013-01-07  North Carolina         2          2    7  January  2013
#
#    quarter day_of_week_num day_of_week_name
# 0        1         Tuesday          Tuesday
# 1        1         Tuesday          Tuesday
# 2        1         Tuesday          Tuesday
# 3        1        Saturday         Saturday
# 4        1          Monday           Monday

# %%
df1.drop('date',axis=True,inplace=True)

# %%
df1['total_victim']=df1['n_killed']+df1['n_injured']#Sum up number of deaths and injuries

# %%
df1.head()
# Out:
#             state  n_killed  n_injured  day    month  year  quarter  \
# 0    Pennsylvania         0          4    1  January  2013        1
# 1      California         1          3    1  January  2013        1
# 2            Ohio         1          3    1  January  2013        1
# 3        Colorado         4          0    5  January  2013        1
# 4  North Carolina         2          2    7  January  2013        1
#
#   day_of_week_num day_of_week_name  total_victim
# 0         Tuesday          Tuesday             4
# 1         Tuesday          Tuesday             4
# 2         Tuesday          Tuesday             4
# 3        Saturday         Saturday             4
# 4          Monday           Monday             4

# %%
df1.isnull().sum()
# Out:
# state               0
# n_killed            0
# n_injured           0
# day                 0
# month               0
# year                0
# quarter             0
# day_of_week_num     0
# day_of_week_name    0
# total_victim        0
# dtype: int64

# %%
df1.groupby('year')['total_victim'].sum() # value_counts,mean() ,catorical/numerical numerical
# Out:
# year
# 2013     1296
# 2014    35559
# 2015    40451
# 2016    45646
# 2017    46214
# 2018     9704
# Name: total_victim, dtype: int64

# %%
df1.groupby('month')['total_victim'].count()
# Out:
# month
# April        18628
# August       21040
# December     18106
# Febuary      18841
# January      23091
# July         21126
# June         18755
# March        22640
# May          19930
# November     17974
# October      19890
# September    19656
# Name: total_victim, dtype: int64

# %%
df1.groupby('day_of_week_num')['total_victim'].count()
# Out:
# day_of_week_num
# Friday       32775
# Monday       33760
# Saturday     36096
# Sunday       37052
# Thrusday     32561
# Tuesday      33307
# Wednesday    34126
# Name: total_victim, dtype: int64

# %%
# what are the total number of victims from gun violence for each US state?
# we first group the number of victims by stae then sum them all up
df1.groupby('state')['total_victim'].count()[4:8].sort_values(ascending=False)
# Out:
# state
# California     16306
# Colorado        3201
# Connecticut     3067
# Delaware        1685
# Name: total_victim, dtype: int64

# %%
# for mean we have to first imort numpy
import numpy as np

# %%
df1.groupby('month')['total_victim'].agg([np.mean,max,min,np.sum])
# Out:
#                mean  max  min    sum
# month
# April      0.713442   20    0  13290
# August     0.757414   13    0  15936
# December   0.765658   35    0  13863
# Febuary    0.709357   34    0  13365
# January    0.735395   16    0  16981
# July       0.782685   25    0  16535
# June       0.782885  103    0  14683
# March      0.711837   17    0  16116
# May        0.756347   27    0  15074
# November   0.775287   47    0  13935
# October    0.731373   19    0  14547
# September  0.739978   15    0  14545
